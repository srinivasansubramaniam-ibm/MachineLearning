# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasansubramaniam-ibm/MachineLearning/blob/master/Photgraph_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import numpy as np
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install dlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=aff201ddb27d80f55a6e4c2777ffc02fcb81a990f2ac705195976771207bbfa4
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import face_recognition

# %%
from google.colab import drive

drive.mount('/content/gdrive/',force_remount=True)
root_path = '/content/gdrive/My Drive/Photoc'
sriniPath = root_path+'/IMG-20230620-WA0002.jpg'
suchitra1Path = root_path+'/suchitra1'
suchitra2Path = root_path+'/suchitra2'
suchitra3Path = root_path+'/suchitra3'
raviPath = root_path+'/ravi'
fatherPath = root_path+'/father'
renjiniPath = root_path+'/renjini'
# Out:
# Mounted at /content/gdrive/

# %%
from tqdm import tqdm
#%%time
i=0
for root, dirs, files in tqdm(os.walk(root_path, topdown=False)):
   for name in files:
      print(name)
      #_, ext = os.path.splitext(name)
      #if (ext == '.jpg'):
          #imgDF.loc[i]=[name,root]
          #print(name)
          #i+=1
# Out:
# 1it [00:00, 238.10it/s]
# IMG-20230620-WA0002.jpg
# IMG-20230620-WA0009.jpg
# aadharsrini.jpg
# aadhar1.jpg
# aa2.jpg
# 20230621_093514.jpg
# 20230621_093459.jpg
# ravi
# father
# suchitra1
# suchitra2
# renjini
# suchitra3

# %%
imgsrinip_bgr = face_recognition.load_image_file(sriniPath)
imgsrinip_rgb = cv2.cvtColor(imgsrinip_bgr,cv2.COLOR_BGR2RGB)
print(sriniPath)
print(suchitra1Path)

imgsuchitra1_bgr = face_recognition.load_image_file(suchitra1Path)
imgsuchitra1_rgb = cv2.cvtColor(imgsuchitra1_bgr,cv2.COLOR_BGR2RGB)
imgsuchitra2_bgr = face_recognition.load_image_file(suchitra2Path)
imgsuchitra2_rgb = cv2.cvtColor(imgsuchitra2_bgr,cv2.COLOR_BGR2RGB)
imgsuchitra3_bgr = face_recognition.load_image_file(suchitra3Path)
imgsuchitra3_rgb = cv2.cvtColor(imgsuchitra3_bgr,cv2.COLOR_BGR2RGB)
imgravi_bgr = face_recognition.load_image_file(raviPath)
imgravi_rgb = cv2.cvtColor(imgravi_bgr,cv2.COLOR_BGR2RGB)
imgrenjini_bgr = face_recognition.load_image_file(renjiniPath)
imgrenjini_rgb = cv2.cvtColor(imgrenjini_bgr,cv2.COLOR_BGR2RGB)
imgfather_bgr = face_recognition.load_image_file(fatherPath)
imgfather_rgb = cv2.cvtColor(imgfather_bgr,cv2.COLOR_BGR2RGB)
# Out:
# /content/gdrive/My Drive/Photoc/IMG-20230620-WA0002.jpg
# /content/gdrive/My Drive/Photoc/suchitra1

# %%
print(sriniPath)
imgsrinip_bgr = face_recognition.load_image_file(sriniPath)
imgsrinip_rgb = cv2.cvtColor(imgsrinip_bgr,cv2.COLOR_BGR2RGB)
#img = cv2.imread(photoFilePath)
#plt.imshow(imgsrinip_bgr)
plt.imshow(imgsrinip_rgb)
#plt.imshow('bgr', imgsrinip_bgr)
#plt.imshow('rgb', imgsrinip_rgb)
# Out:
# /content/gdrive/My Drive/Photoc/IMG-20230620-WA0002.jpg

# %%
faceSrini = face_recognition.face_locations(imgsrinip_rgb)[0]
copySrini = imgsrinip_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copySrini, (faceSrini[3], faceSrini[0]),(faceSrini[1], faceSrini[2]), (255,0,255), 5)
plt.imshow(copySrini)

# %%
faceSuchitra1 = face_recognition.face_locations(imgsuchitra1_rgb)[0]
copySuchitra1 = imgsuchitra1_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copySuchitra1, (faceSuchitra1[3], faceSuchitra1[0]),(faceSuchitra1[1], faceSuchitra1[2]), (255,0,255), 5)
plt.imshow(copySuchitra1)

# %%
faceSuchitra2 = face_recognition.face_locations(imgsuchitra2_rgb)[0]
copySuchitra2 = imgsuchitra2_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copySuchitra2, (faceSuchitra2[3], faceSuchitra2[0]),(faceSuchitra2[1], faceSuchitra2[2]), (255,0,255), 5)
plt.imshow(copySuchitra2)

# %%
faceSuchitra3 = face_recognition.face_locations(imgsuchitra3_rgb)[0]
copySuchitra3 = imgsuchitra3_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copySuchitra3, (faceSuchitra3[3], faceSuchitra3[0]),(faceSuchitra3[1], faceSuchitra3[2]), (255,0,255), 5)
plt.imshow(copySuchitra3)

# %%
faceRenjini = face_recognition.face_locations(imgrenjini_rgb)[0]
copyRenjini = imgrenjini_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copyRenjini, (faceRenjini[3], faceRenjini[0]),(faceRenjini[1], faceRenjini[2]), (255,0,255), 5)
plt.imshow(copyRenjini)

# %%
suchitra1_encodings = face_recognition.face_encodings(imgsuchitra1_rgb)[0]
suchitra2_encodings = face_recognition.face_encodings(imgsuchitra2_rgb)[0]
suchitra3_encodings = face_recognition.face_encodings(imgsuchitra3_rgb)[0]
renjini_encodings = face_recognition.face_encodings(imgrenjini_rgb)[0]

# %%
print("Comparing Suchitra1 and Suchitra2")
# Out:
# Comparing Suchitra1 and Suchitra2

# %%
print(face_recognition.compare_faces([suchitra1_encodings],suchitra2_encodings))
faceDist = face_recognition.face_distance([suchitra1_encodings], suchitra2_encodings)
print(faceDist)
# Out:
# [True]
# [0.22488856]

# %%
print("Comparing Suchitra2 and Suchitra3")
# Out:
# Comparing Suchitra2 and Suchitra3

# %%
print(face_recognition.compare_faces([suchitra2_encodings],suchitra3_encodings))
faceDist23 = face_recognition.face_distance([suchitra2_encodings], suchitra3_encodings)
print(faceDist23)
# Out:
# [True]
# [0.1876082]

# %%
print("Comparing Suchitra3 and Renjini")
# Out:
# Comparing Suchitra1 and Renjini

# %%
print(face_recognition.compare_faces([suchitra3_encodings],renjini_encodings))
faceDistRS = face_recognition.face_distance([suchitra3_encodings], renjini_encodings)
print(faceDistRS)
# Out:
# [True]
# [0.50853443]

# %%
#print(face_recognition.compare_faces([suchitra2_encodings],renjini_encodings))
faceDistRS = face_recognition.face_distance([suchitra2_encodings], renjini_encodings)
print(faceDistRS)
# Out:
# [0.53146212]

# %%
faceDist13 = face_recognition.face_distance([suchitra1_encodings], suchitra3_encodings)
print(faceDist13)
# Out:
# [0.25231636]

# %%
#----------Finding face Location for drawing bounding boxes-------
face = face_recognition.face_locations(imgsrinip_rgb)[0]
copy = imgsrinip_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copy, (face[3], face[0]),(face[1], face[2]), (255,0,255), 2)
plt.imshow(copy)

# %%
aadharFilePath = root_path+'/aa2.jpg'
print(aadharFilePath)
imgsrinia_bgr = face_recognition.load_image_file(aadharFilePath)
imgsrinia_rgb = cv2.cvtColor(imgsrinia_bgr,cv2.COLOR_BGR2RGB)
face = face_recognition.face_locations(imgsrinia_rgb)[0]
copy = imgsrinia_bgr.copy()
#-------------------Drawing the Rectangle-------------------------
cv2.rectangle(copy, (face[3], face[0]),(face[1], face[2]), (0,0,255), 3)
plt.imshow(copy)
# Out:
# /content/gdrive/My Drive/Photoc/aa2.jpg

# %%
imgsrinia_rgb = cv2.cvtColor(imgsrinia_bgr,cv2.COLOR_BGR2RGB)
train_aadhar_encodings = face_recognition.face_encodings(imgsrinia_rgb)[0]

# %%
testPhoto = face_recognition.load_image_file(photoFilePath)
testPhoto = cv2.cvtColor(testPhoto, cv2.COLOR_BGR2RGB)
test_encode = face_recognition.face_encodings(testPhoto)[0]
print(face_recognition.compare_faces([train_aadhar_encodings],test_encode))
# Out:
# [True]
